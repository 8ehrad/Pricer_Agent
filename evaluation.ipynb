# %% [markdown]
# ## Predict Product Prices
#
# ### And now, to evaluate our fine-tuned open source model

# %%
# pip installs

# !pip install -q --upgrade torch==2.5.1+cu124 torchvision==0.20.1+cu124 torchaudio==2.5.1+cu124 --index-url https://download.pytorch.org/whl/cu124
# !pip install -q --upgrade requests==2.32.3 bitsandbytes==0.46.0 transformers==4.48.3 accelerate==1.3.0 datasets==3.2.0 peft==0.14.0 trl==0.14.0 matplotlib wandb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 908.2/908.2 MB 1.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 58.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 75.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 47.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 67.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 106.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.6/209.6 MB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 114.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 MB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 143.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.6/336.6 kB 29.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 35.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.8/374.8 kB 34.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.9/313.9 kB 26.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 150.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 15.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 72.3 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.3 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.9.0 which is incompatible.
# google-adk 1.15.1 requires requests<3.0.0,>=2.32.4, but you have requests 2.32.3 which is incompatible.

# %%
# imports

import os
import re
import math
from tqdm import tqdm
from google.colab import userdata
from huggingface_hub import login
import torch
import torch.nn.functional as F
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, set_seed
from datasets import load_dataset, Dataset, DatasetDict
from datetime import datetime
from peft import PeftModel
import matplotlib.pyplot as plt

# %%
# Constants

BASE_MODEL = "meta-llama/Meta-Llama-3.1-8B"
PROJECT_NAME = "pricer"
HF_USER = "behrad"

# The run itself

RUN_NAME = "2025-08-28_08.48.14"
PROJECT_RUN_NAME = f"{PROJECT_NAME}-{RUN_NAME}"
REVISION = None
FINETUNED_MODEL = f"{HF_USER}/{PROJECT_RUN_NAME}"

# Data

DATASET_NAME = f"{HF_USER}/pricer-data"

# Hyperparameters for QLoRA

QUANT_4_BIT = True

# %matplotlib inline

# Used for writing to output in color

GREEN = "\033[92m"
YELLOW = "\033[93m"
RED = "\033[91m"
RESET = "\033[0m"
COLOR_MAP = {"red":RED, "orange": YELLOW, "green": GREEN}

# %% [markdown]
# ### Log in to HuggingFace
#
# If you don't already have a HuggingFace account, visit https://huggingface.co to sign up and create a token.
#
# Then select the Secrets for this Notebook by clicking on the key icon in the left, and add a new secret called `HF_TOKEN` with the value as your token.

# %%
# Log in to HuggingFace

hf_token = userdata.get('HF_TOKEN')
login(hf_token, add_to_git_credential=True)

# %%
dataset = load_dataset(DATASET_NAME)
train = dataset['train']
test = dataset['test']
# Out:
# README.md:   0%|          | 0.00/416 [00:00<?, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/185M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/914k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/400000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
test[0]
# Out:
# {'text': "How much does this cost to the nearest dollar?\n\nOEM AC Compressor w/A/C Repair Kit For Ford F150 F-150 V8 & Lincoln Mark LT 2007 2008 - BuyAutoParts NEW\nAs one of the world's largest automotive parts suppliers, our parts are trusted every day by mechanics and vehicle owners worldwide. This A/C Compressor and Components Kit is manufactured and tested to the strictest OE standards for unparalleled performance. Built for trouble-free ownership and 100% visually inspected and quality tested, this A/C Compressor and Components Kit is backed by our 100% satisfaction guarantee. Guaranteed Exact Fit for easy installation 100% BRAND NEW, premium ISO/TS 16949 quality - tested to meet or exceed OEM specifications Engineered for superior durability, backed by industry-leading unlimited-mileage warranty Included in this K\n\nPrice is $",
#  'price': 374.41}

# %% [markdown]
# ## Now load the Tokenizer and Model

# %%
# pick the right quantization

if QUANT_4_BIT:
  quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.bfloat16,
    bnb_4bit_quant_type="nf4"
  )
else:
  quant_config = BitsAndBytesConfig(
    load_in_8bit=True,
    bnb_8bit_compute_dtype=torch.bfloat16
  )

# %%
# Load the Tokenizer and the Model

tokenizer = AutoTokenizer.from_pretrained(BASE_MODEL, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

base_model = AutoModelForCausalLM.from_pretrained(
    BASE_MODEL,
    quantization_config=quant_config,
    device_map="auto",
)
base_model.generation_config.pad_token_id = tokenizer.pad_token_id

# Load the fine-tuned model with PEFT
if REVISION:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL, revision=REVISION)
else:
  fine_tuned_model = PeftModel.from_pretrained(base_model, FINETUNED_MODEL)


print(f"Memory footprint: {fine_tuned_model.get_memory_footprint() / 1e6:.1f} MB")
# Out:
# tokenizer_config.json:   0%|          | 0.00/50.5k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.09M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/73.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/826 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/185 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/752 [00:00<?, ?B/s]
# adapter_model.safetensors:   0%|          | 0.00/109M [00:00<?, ?B/s]
# Memory footprint: 5700.6 MB

# %%
fine_tuned_model
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(128256, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=32, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=32, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#           )
#         )
#         (norm): LlamaRMSNorm((4096,), eps=1e-05)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
#     )
#   )
# )

# %% [markdown]
# ## Use the model in inference mode

# %%
def extract_price(s):
    if "Price is $" in s:
      contents = s.split("Price is $")[1]
      contents = contents.replace(',','')
      match = re.search(r"[-+]?\d*\.\d+|\d+", contents)
      return float(match.group()) if match else 0
    return 0

# %%
extract_price("Price is $a fabulous 899.99 or so")
# Out:
# 899.99

# %%
# Original prediction function takes the most likely next token

def model_predict(prompt):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to("cuda")
    attention_mask = torch.ones(inputs.shape, device="cuda")
    outputs = fine_tuned_model.generate(inputs, attention_mask=attention_mask, max_new_tokens=3, num_return_sequences=1)
    response = tokenizer.decode(outputs[0])
    return extract_price(response)

# %%
# An improved prediction function takes a weighted average of the top 3 choices

top_K = 3

def improved_model_predict(prompt, device="cuda"):
    set_seed(42)
    inputs = tokenizer.encode(prompt, return_tensors="pt").to(device)
    attention_mask = torch.ones(inputs.shape, device=device)

    with torch.no_grad():
        outputs = fine_tuned_model(inputs, attention_mask=attention_mask)
        next_token_logits = outputs.logits[:, -1, :].to('cpu')

    next_token_probs = F.softmax(next_token_logits, dim=-1)
    top_prob, top_token_id = next_token_probs.topk(top_K)
    prices, weights = [], []
    for i in range(top_K):
      predicted_token = tokenizer.decode(top_token_id[0][i])
      probability = top_prob[0][i]
      try:
        result = float(predicted_token)
      except ValueError as e:
        result = 0.0
      if result > 0:
        prices.append(result)
        weights.append(probability)
    if not prices:
      return 0.0, 0.0
    total = sum(weights)
    weighted_prices = [price * weight / total for price, weight in zip(prices, weights)]
    return sum(weighted_prices).item()

# %%
class Tester:

    def __init__(self, predictor, data, title=None, size=250):
        self.predictor = predictor
        self.data = data
        self.title = title or predictor.__name__.replace("_", " ").title()
        self.size = size
        self.guesses = []
        self.truths = []
        self.errors = []
        self.sles = []
        self.colors = []

    def color_for(self, error, truth):
        if error<40 or error/truth < 0.2:
            return "green"
        elif error<80 or error/truth < 0.4:
            return "orange"
        else:
            return "red"

    def run_datapoint(self, i):
        datapoint = self.data[i]
        guess = self.predictor(datapoint["text"])
        truth = datapoint["price"]
        error = abs(guess - truth)
        log_error = math.log(truth+1) - math.log(guess+1)
        sle = log_error ** 2
        color = self.color_for(error, truth)
        title = datapoint["text"].split("\n\n")[1][:20] + "..."
        self.guesses.append(guess)
        self.truths.append(truth)
        self.errors.append(error)
        self.sles.append(sle)
        self.colors.append(color)
        print(f"{COLOR_MAP[color]}{i+1}: Guess: ${guess:,.2f} Truth: ${truth:,.2f} Error: ${error:,.2f} SLE: {sle:,.2f} Item: {title}{RESET}")

    def chart(self, title):
        max_error = max(self.errors)
        plt.figure(figsize=(12, 8))
        max_val = max(max(self.truths), max(self.guesses))
        plt.plot([0, max_val], [0, max_val], color='deepskyblue', lw=2, alpha=0.6)
        plt.scatter(self.truths, self.guesses, s=3, c=self.colors)
        plt.xlabel('Ground Truth')
        plt.ylabel('Model Estimate')
        plt.xlim(0, max_val)
        plt.ylim(0, max_val)
        plt.title(title)
        plt.show()

    def report(self):
        average_error = sum(self.errors) / self.size
        rmsle = math.sqrt(sum(self.sles) / self.size)
        hits = sum(1 for color in self.colors if color=="green")
        title = f"{self.title} Error=${average_error:,.2f} RMSLE={rmsle:,.2f} Hits={hits/self.size*100:.1f}%"
        self.chart(title)

    def run(self):
        self.error = 0
        for i in range(self.size):
            self.run_datapoint(i)
        self.report()

    @classmethod
    def test(cls, function, data):
        cls(function, data).run()

# %%
Tester.test(improved_model_predict, test)
# Out:
# 1: Guess: $325.00 Truth: $374.41 Error: $49.41 SLE: 0.02 Item: OEM AC Compressor w/...
# 2: Guess: $158.88 Truth: $225.11 Error: $66.24 SLE: 0.12 Item: Motorcraft YB3125 Fa...
# 3: Guess: $54.06 Truth: $61.68 Error: $7.62 SLE: 0.02 Item: Dorman Front Washer ...
# 4: Guess: $552.50 Truth: $599.99 Error: $47.49 SLE: 0.01 Item: HP Premium HD Plus T...
# 5: Guess: $11.06 Truth: $16.99 Error: $5.93 SLE: 0.16 Item: Super Switch Pickup ...
# 6: Guess: $11.04 Truth: $31.99 Error: $20.95 SLE: 1.02 Item: Horror Bookmarks, Re...
# 7: Guess: $74.88 Truth: $101.79 Error: $26.92 SLE: 0.09 Item: SK6241 - Stinger 4 G...
# 8: Guess: $355.25 Truth: $289.00 Error: $66.25 SLE: 0.04 Item: Godox ML60Bi LED Lig...
# 9: Guess: $799.00 Truth: $635.86 Error: $163.14 SLE: 0.05 Item: Randall G3 Plus Comb...
# 10: Guess: $97.31 Truth: $65.99 Error: $31.32 SLE: 0.15 Item: HOLDWILL 6 Pack LED ...
# 11: Guess: $238.62 Truth: $254.21 Error: $15.59 SLE: 0.00 Item: Viking Horns 3 Gallo...
# 12: Guess: $342.50 Truth: $412.99 Error: $70.49 SLE: 0.03 Item: CURT 70110 Custom To...
# 13: Guess: $258.25 Truth: $205.50 Error: $52.75 SLE: 0.05 Item: Solar HAMMERED BRONZ...
# 14: Guess: $303.00 Truth: $248.23 Error: $54.77 SLE: 0.04 Item: COSTWAY Electric Tum...
# 15: Guess: $347.25 Truth: $399.00 Error: $51.75 SLE: 0.02 Item: FREE SIGNAL TV Trans...
# 16: Guess: $361.00 Truth: $373.94 Error: $12.94 SLE: 0.00 Item: Bilstein 5100 Monotu...
# 17: Guess: $98.12 Truth: $92.89 Error: $5.23 SLE: 0.00 Item: Sangean K-200 Multi-...
# 18: Guess: $141.38 Truth: $51.99 Error: $89.38 SLE: 0.98 Item: Charles Leonard Magn...
# 19: Guess: $246.38 Truth: $179.00 Error: $67.38 SLE: 0.10 Item: Gigabyte AMD Radeon ...
# 20: Guess: $19.06 Truth: $19.42 Error: $0.36 SLE: 0.00 Item: 3dRose LLC 8 x 8 x 0...
# 21: Guess: $415.50 Truth: $539.95 Error: $124.45 SLE: 0.07 Item: ROKINON 85mm F1.4 Au...
# 22: Guess: $125.75 Truth: $147.67 Error: $21.92 SLE: 0.03 Item: Headlight Assembly C...
# 23: Guess: $29.97 Truth: $24.99 Error: $4.98 SLE: 0.03 Item: ASI NAUTICAL 2.5 Inc...
# 24: Guess: $110.56 Truth: $149.00 Error: $38.44 SLE: 0.09 Item: Behringer TUBE OVERD...
# 25: Guess: $13.64 Truth: $16.99 Error: $3.35 SLE: 0.04 Item: Fun Express Insect F...
# 26: Guess: $10.00 Truth: $7.99 Error: $2.01 SLE: 0.04 Item: WAFJAMF Roller Stamp...
# 27: Guess: $177.12 Truth: $199.99 Error: $22.87 SLE: 0.01 Item: Capulina Tiffany Flo...
# 28: Guess: $276.75 Truth: $251.45 Error: $25.30 SLE: 0.01 Item: Apple Watch Series 6...
# 29: Guess: $241.38 Truth: $231.62 Error: $9.75 SLE: 0.00 Item: ICON 01725 Tandem Ax...
# 30: Guess: $206.88 Truth: $135.00 Error: $71.88 SLE: 0.18 Item: SanDisk 128GB Ultra ...
# 31: Guess: $293.50 Truth: $356.62 Error: $63.12 SLE: 0.04 Item: Velvac - 715427
# 2020...
# 32: Guess: $252.75 Truth: $257.99 Error: $5.24 SLE: 0.00 Item: TCMT Passenger Backr...
# 33: Guess: $35.31 Truth: $27.99 Error: $7.32 SLE: 0.05 Item: Alnicov 63.5MM Brass...
# 34: Guess: $94.88 Truth: $171.20 Error: $76.32 SLE: 0.34 Item: Subaru Forester Outb...
# 35: Guess: $397.00 Truth: $225.00 Error: $172.00 SLE: 0.32 Item: Richmond Auto Uphols...
# 36: Guess: $190.00 Truth: $105.00 Error: $85.00 SLE: 0.35 Item: AP-39 Automotive Pai...
# 37: Guess: $503.25 Truth: $299.99 Error: $203.26 SLE: 0.27 Item: Road Top Wireless Ca...
# 38: Guess: $611.50 Truth: $535.09 Error: $76.41 SLE: 0.02 Item: Gibson Performance E...
# 39: Guess: $22.67 Truth: $12.33 Error: $10.34 SLE: 0.33 Item: Bella Tunno Happy Li...
# 40: Guess: $92.38 Truth: $84.99 Error: $7.39 SLE: 0.01 Item: CANMORE H300 Handhel...
# 41: Guess: $16.94 Truth: $15.99 Error: $0.95 SLE: 0.00 Item: DCPOWER AC Adapter C...
# 42: Guess: $54.91 Truth: $62.44 Error: $7.53 SLE: 0.02 Item: Sharp, Commercial De...
# 43: Guess: $116.75 Truth: $82.99 Error: $33.76 SLE: 0.11 Item: Melissa & Doug Lifel...
# 44: Guess: $433.25 Truth: $599.95 Error: $166.70 SLE: 0.11 Item: Sony SSCS8 2-Way Cen...
# 45: Guess: $234.25 Truth: $194.99 Error: $39.26 SLE: 0.03 Item: ASUS Chromebook CX1,...
# 46: Guess: $501.00 Truth: $344.95 Error: $156.05 SLE: 0.14 Item: FiiO X7 32GB Hi-Res ...
# 47: Guess: $60.25 Truth: $37.99 Error: $22.26 SLE: 0.20 Item: TORRO Leather Case C...
# 48: Guess: $247.25 Truth: $224.35 Error: $22.90 SLE: 0.01 Item: Universal Air Condit...
# 49: Guess: $710.50 Truth: $814.00 Error: $103.50 SLE: 0.02 Item: Street Series Stainl...
# 50: Guess: $428.00 Truth: $439.88 Error: $11.88 SLE: 0.00 Item: Lenovo IdeaPad 3 Lap...
# 51: Guess: $343.75 Truth: $341.43 Error: $2.32 SLE: 0.00 Item: Access Bed Covers To...
# 52: Guess: $65.06 Truth: $46.78 Error: $18.28 SLE: 0.10 Item: G.I. JOE Hasbro 3 3/...
# 53: Guess: $185.62 Truth: $171.44 Error: $14.19 SLE: 0.01 Item: T&S Brass Double Pan...
# 54: Guess: $391.00 Truth: $458.00 Error: $67.00 SLE: 0.02 Item: ZTUOAUMA Fuel Inject...
# 55: Guess: $213.00 Truth: $130.75 Error: $82.25 SLE: 0.24 Item: Hp Prime Graphing Ca...
# 56: Guess: $65.50 Truth: $83.81 Error: $18.31 SLE: 0.06 Item: Lowrance Nmea 2000 2...
# 57: Guess: $252.75 Truth: $386.39 Error: $133.64 SLE: 0.18 Item: Jeep Genuine Accesso...
# 58: Guess: $204.88 Truth: $169.00 Error: $35.88 SLE: 0.04 Item: GODOX CB-06 Hard Car...
# 59: Guess: $21.00 Truth: $17.95 Error: $3.05 SLE: 0.02 Item: Au-Tomotive Gold, IN...
# 60: Guess: $260.25 Truth: $269.00 Error: $8.75 SLE: 0.00 Item: Snailfly Black Roof ...
# 61: Guess: $77.19 Truth: $77.77 Error: $0.58 SLE: 0.00 Item: KING SHA Anti Glare ...
# 62: Guess: $47.88 Truth: $88.99 Error: $41.11 SLE: 0.37 Item: APS Compatible with ...
# 63: Guess: $367.75 Truth: $364.41 Error: $3.34 SLE: 0.00 Item: Wilwood Engineering ...
# 64: Guess: $152.25 Truth: $127.03 Error: $25.22 SLE: 0.03 Item: ACDelco Gold Starter...
# 65: Guess: $656.00 Truth: $778.95 Error: $122.95 SLE: 0.03 Item: UWS Matte Black Heav...
# 66: Guess: $242.00 Truth: $206.66 Error: $35.34 SLE: 0.02 Item: Dell Latitude E5440 ...
# 67: Guess: $31.59 Truth: $35.94 Error: $4.35 SLE: 0.02 Item: (Plug and Play) Spar...
# 68: Guess: $235.88 Truth: $149.00 Error: $86.88 SLE: 0.21 Item: The Ultimate Roadsid...
# 69: Guess: $195.62 Truth: $251.98 Error: $56.35 SLE: 0.06 Item: Brand New 18 x 8.5 R...
# 70: Guess: $216.50 Truth: $160.00 Error: $56.50 SLE: 0.09 Item: Headlight Headlamp L...
# 71: Guess: $40.12 Truth: $39.99 Error: $0.13 SLE: 0.00 Item: Lilo And Stitch Delu...
# 72: Guess: $248.75 Truth: $362.41 Error: $113.66 SLE: 0.14 Item: AC Compressor & A/C ...
# 73: Guess: $416.00 Truth: $344.00 Error: $72.00 SLE: 0.04 Item: House Of Troy Pinnac...
# 74: Guess: $33.81 Truth: $25.09 Error: $8.72 SLE: 0.08 Item: Juno T29 WH Floating...
# 75: Guess: $79.38 Truth: $175.95 Error: $96.57 SLE: 0.62 Item: Sherman GO-PARTS - f...
# 76: Guess: $316.75 Truth: $132.64 Error: $184.11 SLE: 0.75 Item: Roland RPU-3 Electro...
# 77: Guess: $349.50 Truth: $422.99 Error: $73.49 SLE: 0.04 Item: Rockland VMI14 12,00...
# 78: Guess: $137.62 Truth: $146.48 Error: $8.85 SLE: 0.00 Item: Max Advanced Brakes ...
# 79: Guess: $156.25 Truth: $156.83 Error: $0.58 SLE: 0.00 Item: Quality-Built 11030 ...
# 80: Guess: $146.62 Truth: $251.99 Error: $105.37 SLE: 0.29 Item: Lucida LG-510 Studen...
# 81: Guess: $313.75 Truth: $940.33 Error: $626.58 SLE: 1.20 Item: Longacre Aluminum Tu...
# 82: Guess: $48.00 Truth: $52.99 Error: $4.99 SLE: 0.01 Item: Motion Pro Adjustabl...
# 83: Guess: $258.75 Truth: $219.95 Error: $38.80 SLE: 0.03 Item: Glyph Thunderbolt 3 ...
# 84: Guess: $280.50 Truth: $441.03 Error: $160.53 SLE: 0.20 Item: TOYO Open Country MT...
# 85: Guess: $180.50 Truth: $168.98 Error: $11.52 SLE: 0.00 Item: Razer Seiren X USB S...
# 86: Guess: $3.91 Truth: $2.49 Error: $1.42 SLE: 0.12 Item: Happy Birthday to Da...
# 87: Guess: $90.62 Truth: $98.62 Error: $8.00 SLE: 0.01 Item: Little Tikes My Real...
# 88: Guess: $263.00 Truth: $256.95 Error: $6.05 SLE: 0.00 Item: Studio M Peace and H...
# 89: Guess: $24.62 Truth: $30.99 Error: $6.36 SLE: 0.05 Item: MyVolts 12V Power Su...
# 90: Guess: $567.00 Truth: $569.84 Error: $2.84 SLE: 0.00 Item: Dell Latitude 7212 R...
# 91: Guess: $211.38 Truth: $177.99 Error: $33.38 SLE: 0.03 Item: Covermates Contour F...
# 92: Guess: $997.50 Truth: $997.99 Error: $0.49 SLE: 0.00 Item: Westin Black HDX Gri...
# 93: Guess: $265.00 Truth: $219.00 Error: $46.00 SLE: 0.04 Item: Fieldpiece JL2 Job L...
# 94: Guess: $266.25 Truth: $225.55 Error: $40.70 SLE: 0.03 Item: hansgrohe Talis S Mo...
# 95: Guess: $801.50 Truth: $495.95 Error: $305.55 SLE: 0.23 Item: G-Technology G-SPEED...
# 96: Guess: $856.00 Truth: $942.37 Error: $86.37 SLE: 0.01 Item: DreamLine Shower Doo...
# 97: Guess: $2.94 Truth: $1.94 Error: $1.00 SLE: 0.09 Item: Sanctuary Square Bac...
# 98: Guess: $325.50 Truth: $284.34 Error: $41.16 SLE: 0.02 Item: Pelican Protector 17...
# 99: Guess: $156.00 Truth: $171.90 Error: $15.90 SLE: 0.01 Item: Brock Replacement Dr...
# 100: Guess: $273.00 Truth: $144.99 Error: $128.01 SLE: 0.40 Item: Carlinkit Ai Box Min...
# 101: Guess: $409.00 Truth: $470.47 Error: $61.47 SLE: 0.02 Item: StarDot YouTube Live...
# 102: Guess: $76.69 Truth: $66.95 Error: $9.74 SLE: 0.02 Item: Atomic Compatible ME...
# 103: Guess: $90.38 Truth: $117.00 Error: $26.62 SLE: 0.07 Item: Bandai Awakening of ...
# 104: Guess: $252.75 Truth: $172.14 Error: $80.61 SLE: 0.15 Item: Fit System 62135G Pa...
# 105: Guess: $335.50 Truth: $392.74 Error: $57.24 SLE: 0.02 Item: Black Horse Black Al...
# 106: Guess: $22.64 Truth: $16.99 Error: $5.65 SLE: 0.07 Item: Dearsun Twinkle Star...
# 107: Guess: $1.84 Truth: $1.34 Error: $0.50 SLE: 0.04 Item: Pokemon - Gallade Sp...
# 108: Guess: $235.50 Truth: $349.98 Error: $114.48 SLE: 0.16 Item: Ibanez GIO Series Cl...
# 109: Guess: $374.50 Truth: $370.71 Error: $3.79 SLE: 0.00 Item: Set 2 Heavy Duty 12 ...
# 110: Guess: $85.50 Truth: $65.88 Error: $19.62 SLE: 0.07 Item: Hairpin Table Legs 2...
# 111: Guess: $272.75 Truth: $229.99 Error: $42.76 SLE: 0.03 Item: Marada Racing Seat w...
# 112: Guess: $5.66 Truth: $9.14 Error: $3.48 SLE: 0.18 Item: Remington Industries...
# 113: Guess: $431.50 Truth: $199.00 Error: $232.50 SLE: 0.59 Item: Acer Ultrabook, Inte...
# 114: Guess: $280.25 Truth: $109.99 Error: $170.26 SLE: 0.86 Item: ICBEAMER 7 RGB LED H...
# 115: Guess: $402.75 Truth: $570.42 Error: $167.67 SLE: 0.12 Item: R1 Concepts Front Re...
# 116: Guess: $249.38 Truth: $279.99 Error: $30.62 SLE: 0.01 Item: Camplux 2.64 GPM Tan...
# 117: Guess: $29.56 Truth: $30.99 Error: $1.43 SLE: 0.00 Item: KNOKLOCK 10 Pack 3.7...
# 118: Guess: $40.00 Truth: $31.99 Error: $8.01 SLE: 0.05 Item: Valley Enterprises Y...
# 119: Guess: $29.59 Truth: $15.90 Error: $13.69 SLE: 0.35 Item: G9 LED Light 100W re...
# 120: Guess: $90.50 Truth: $45.99 Error: $44.51 SLE: 0.44 Item: ZCHAOZ 4 Lights Anti...
# 121: Guess: $257.00 Truth: $113.52 Error: $143.48 SLE: 0.66 Item: Honeywell Honeywell ...
# 122: Guess: $254.00 Truth: $516.99 Error: $262.99 SLE: 0.50 Item: Patriot Exhaust 1-7/...
# 123: Guess: $118.38 Truth: $196.99 Error: $78.62 SLE: 0.26 Item: Fitrite Autopart New...
# 124: Guess: $149.00 Truth: $46.55 Error: $102.45 SLE: 1.32 Item: Technical Precision ...
# 125: Guess: $313.50 Truth: $356.99 Error: $43.49 SLE: 0.02 Item: Covercraft Carhartt ...
# 126: Guess: $343.75 Truth: $319.95 Error: $23.80 SLE: 0.01 Item: Sennheiser SD Pro 2 ...
# 127: Guess: $84.19 Truth: $96.06 Error: $11.87 SLE: 0.02 Item: Hitachi Mass Air Flo...
# 128: Guess: $167.00 Truth: $190.99 Error: $23.99 SLE: 0.02 Item: AmScope LED Cordless...
# 129: Guess: $117.88 Truth: $257.95 Error: $140.07 SLE: 0.61 Item: Front Left Driver Si...
# 130: Guess: $51.81 Truth: $62.95 Error: $11.14 SLE: 0.04 Item: Premium Replica Hubc...
# 131: Guess: $42.47 Truth: $47.66 Error: $5.19 SLE: 0.01 Item: Excellerations Phoni...
# 132: Guess: $249.12 Truth: $226.99 Error: $22.13 SLE: 0.01 Item: RC4WD BigDog Dual Ax...
# 133: Guess: $261.25 Truth: $359.95 Error: $98.70 SLE: 0.10 Item: Unknown Stage 2 Clut...
# 134: Guess: $75.38 Truth: $78.40 Error: $3.03 SLE: 0.00 Item: Dodge Ram 1500 Mopar...
# 135: Guess: $180.50 Truth: $172.77 Error: $7.73 SLE: 0.00 Item: Pro Comp Alloys Seri...
# 136: Guess: $302.75 Truth: $316.45 Error: $13.70 SLE: 0.00 Item: Detroit Axle - Front...
# 137: Guess: $135.12 Truth: $87.99 Error: $47.14 SLE: 0.18 Item: ECCPP Rear Wheel Axl...
# 138: Guess: $242.25 Truth: $226.63 Error: $15.62 SLE: 0.00 Item: Dell Latitude E6520 ...
# 139: Guess: $22.59 Truth: $31.49 Error: $8.90 SLE: 0.10 Item: F FIERCE CYCLE 251pc...
# 140: Guess: $226.62 Truth: $196.00 Error: $30.62 SLE: 0.02 Item: Flash Furniture 4 Pk...
# 141: Guess: $61.00 Truth: $78.40 Error: $17.40 SLE: 0.06 Item: B&M 30287 Throttle V...
# 142: Guess: $152.00 Truth: $116.25 Error: $35.75 SLE: 0.07 Item: Gates TCK226 PowerGr...
# 143: Guess: $134.38 Truth: $112.78 Error: $21.59 SLE: 0.03 Item: Monroe Shocks & Stru...
# 144: Guess: $65.25 Truth: $27.32 Error: $37.93 SLE: 0.72 Item: Feit Electric 35W EQ...
# 145: Guess: $106.62 Truth: $145.91 Error: $39.28 SLE: 0.10 Item: Yellow Jacket 2806 C...
# 146: Guess: $159.25 Truth: $171.09 Error: $11.84 SLE: 0.01 Item: Garage-Pro Tailgate ...
# 147: Guess: $104.62 Truth: $167.95 Error: $63.32 SLE: 0.22 Item: 3M Perfect It Buffin...
# 148: Guess: $58.75 Truth: $28.49 Error: $30.26 SLE: 0.50 Item: Chinese Style Dollho...
# 149: Guess: $104.69 Truth: $122.23 Error: $17.54 SLE: 0.02 Item: Generic NRG Innovati...
# 150: Guess: $35.00 Truth: $32.99 Error: $2.01 SLE: 0.00 Item: Learning Resources C...
# 151: Guess: $113.75 Truth: $71.20 Error: $42.55 SLE: 0.21 Item: Bosch Automotive 154...
# 152: Guess: $59.00 Truth: $112.75 Error: $53.75 SLE: 0.41 Item: Case of 24-2 Inch Bl...
# 153: Guess: $96.69 Truth: $142.43 Error: $45.74 SLE: 0.15 Item: MOCA Engine Water Pu...
# 154: Guess: $271.25 Truth: $398.99 Error: $127.74 SLE: 0.15 Item: SAREMAS Foot Step Ba...
# 155: Guess: $574.00 Truth: $449.00 Error: $125.00 SLE: 0.06 Item: Gretsch G9210 Square...
# 156: Guess: $208.75 Truth: $189.00 Error: $19.75 SLE: 0.01 Item: NikoMaku Mirror Dash...
# 157: Guess: $158.38 Truth: $120.91 Error: $37.47 SLE: 0.07 Item: Fenix HP25R v2.0 USB...
# 158: Guess: $181.88 Truth: $203.53 Error: $21.66 SLE: 0.01 Item: R&L Racing Heavy Dut...
# 159: Guess: $343.25 Truth: $349.99 Error: $6.74 SLE: 0.00 Item: Garmin GPSMAP 64sx, ...
# 160: Guess: $12.69 Truth: $34.35 Error: $21.66 SLE: 0.90 Item: Brown 5-7/8 X 8-1/2 ...
# 161: Guess: $307.25 Truth: $384.99 Error: $77.74 SLE: 0.05 Item: GAOMON PD2200 Pen Di...
# 162: Guess: $168.50 Truth: $211.00 Error: $42.50 SLE: 0.05 Item: VXMOTOR for 97-03 Fo...
# 163: Guess: $204.50 Truth: $129.00 Error: $75.50 SLE: 0.21 Item: HP EliteBook 2540p I...
# 164: Guess: $29.39 Truth: $111.45 Error: $82.06 SLE: 1.71 Item: Green EPX Mixing Noz...
# 165: Guess: $41.00 Truth: $81.12 Error: $40.12 SLE: 0.45 Item: Box Partners 6 1/4 x...
# 166: Guess: $346.00 Truth: $457.08 Error: $111.08 SLE: 0.08 Item: Vixen Air 1/2 NPT Ai...
# 167: Guess: $119.44 Truth: $49.49 Error: $69.95 SLE: 0.76 Item: Smart Floor Lamp, Mu...
# 168: Guess: $74.56 Truth: $80.56 Error: $6.00 SLE: 0.01 Item: SOZG 324mm Wheelbase...
# 169: Guess: $272.50 Truth: $278.39 Error: $5.89 SLE: 0.00 Item: Mickey Thompson ET S...
# 170: Guess: $312.75 Truth: $364.50 Error: $51.75 SLE: 0.02 Item: Pirelli 106W XL RFT ...
# 171: Guess: $549.00 Truth: $378.99 Error: $170.01 SLE: 0.14 Item: Torklift C3212 Rear ...
# 172: Guess: $172.25 Truth: $165.28 Error: $6.97 SLE: 0.00 Item: Cardone Remanufactur...
# 173: Guess: $51.00 Truth: $56.74 Error: $5.74 SLE: 0.01 Item: Kidde AccessPoint 00...
# 174: Guess: $194.62 Truth: $307.95 Error: $113.32 SLE: 0.21 Item: 3M Protecta Self Ret...
# 175: Guess: $91.06 Truth: $38.00 Error: $53.06 SLE: 0.74 Item: Plantronics Wired He...
# 176: Guess: $109.88 Truth: $53.00 Error: $56.88 SLE: 0.52 Item: Logitech K750 Wirele...
# 177: Guess: $555.50 Truth: $498.00 Error: $57.50 SLE: 0.01 Item: Olympus PEN E-PL9 Bo...
# 178: Guess: $152.38 Truth: $53.99 Error: $98.38 SLE: 1.05 Item: Beck/Arnley Hub & Be...
# 179: Guess: $347.75 Truth: $350.00 Error: $2.25 SLE: 0.00 Item: Eibach Pro-Kit Perfo...
# 180: Guess: $308.00 Truth: $299.95 Error: $8.05 SLE: 0.00 Item: LEGO DC Batman 1989 ...
# 181: Guess: $102.62 Truth: $94.93 Error: $7.69 SLE: 0.01 Item: Kingston Brass Resto...
# 182: Guess: $372.00 Truth: $379.00 Error: $7.00 SLE: 0.00 Item: Polk Vanishing Serie...
# 183: Guess: $288.25 Truth: $299.95 Error: $11.70 SLE: 0.00 Item: Spec-D Tuning LED Pr...
# 184: Guess: $12.34 Truth: $24.99 Error: $12.65 SLE: 0.44 Item: RICHMOND & FINCH Air...
# 185: Guess: $85.19 Truth: $41.04 Error: $44.15 SLE: 0.52 Item: LFA Industries - mm ...
# 186: Guess: $267.00 Truth: $327.90 Error: $60.90 SLE: 0.04 Item: SAUTVS LED Headlight...
# 187: Guess: $21.00 Truth: $10.99 Error: $10.01 SLE: 0.37 Item: 2 Pack Combo Womens ...
# 188: Guess: $15.41 Truth: $14.99 Error: $0.42 SLE: 0.00 Item: Arepa - Venezuelan c...
# 189: Guess: $24.55 Truth: $84.95 Error: $60.40 SLE: 1.47 Item: Schlage Lock Company...
# 190: Guess: $100.69 Truth: $111.00 Error: $10.31 SLE: 0.01 Item: Techni Mobili White ...
# 191: Guess: $170.62 Truth: $123.73 Error: $46.89 SLE: 0.10 Item: Special Lite Product...
# 192: Guess: $396.00 Truth: $557.38 Error: $161.38 SLE: 0.12 Item: Tascam Digital Porta...
# 193: Guess: $86.25 Truth: $95.55 Error: $9.30 SLE: 0.01 Item: Glow Lighting Vista ...
# 194: Guess: $223.75 Truth: $154.00 Error: $69.75 SLE: 0.14 Item: Z3 Wind Deflector, S...
# 195: Guess: $161.00 Truth: $198.99 Error: $37.99 SLE: 0.04 Item: Olympus E-20 5MP Dig...
# 196: Guess: $264.75 Truth: $430.44 Error: $165.69 SLE: 0.23 Item: PHYNEDI 1 1000 World...
# 197: Guess: $26.75 Truth: $45.67 Error: $18.92 SLE: 0.27 Item: YANGHUAN Unstable Un...
# 198: Guess: $292.75 Truth: $249.00 Error: $43.75 SLE: 0.03 Item: Interlogix NetworX T...
# 199: Guess: $30.31 Truth: $42.99 Error: $12.68 SLE: 0.12 Item: Steering Damper,Univ...
# 200: Guess: $115.38 Truth: $181.33 Error: $65.96 SLE: 0.20 Item: Amprobe TIC 410A Hot...
# 201: Guess: $6.92 Truth: $6.03 Error: $0.89 SLE: 0.01 Item: MyCableMart 3.5mm Pl...
# 202: Guess: $50.03 Truth: $29.99 Error: $20.04 SLE: 0.25 Item: OtterBox + Pop Symme...
# 203: Guess: $797.00 Truth: $899.00 Error: $102.00 SLE: 0.01 Item: Dell XPS Desktop ( I...
# 204: Guess: $361.25 Truth: $399.99 Error: $38.74 SLE: 0.01 Item: Franklin Iron Works ...
# 205: Guess: $10.98 Truth: $4.66 Error: $6.32 SLE: 0.56 Item: Avery Legal Dividers...
# 206: Guess: $263.50 Truth: $261.41 Error: $2.09 SLE: 0.00 Item: Moen 8346 Commercial...
# 207: Guess: $153.00 Truth: $136.97 Error: $16.03 SLE: 0.01 Item: Carlisle Versa Trail...
# 208: Guess: $96.25 Truth: $79.00 Error: $17.25 SLE: 0.04 Item: SUNWAYFOTO 44mm Trip...
# 209: Guess: $305.50 Truth: $444.99 Error: $139.49 SLE: 0.14 Item: NanoBeam AC 4 Units ...
# 210: Guess: $399.00 Truth: $411.94 Error: $12.94 SLE: 0.00 Item: WULF 4 Front 2 Rear ...
# 211: Guess: $144.50 Truth: $148.40 Error: $3.90 SLE: 0.00 Item: Alera ALEVABFMC Vale...
# 212: Guess: $264.00 Truth: $244.99 Error: $19.01 SLE: 0.01 Item: YU-GI-OH! Ignition A...
# 213: Guess: $96.25 Truth: $86.50 Error: $9.75 SLE: 0.01 Item: 48 x 36 Extra-Large ...
# 214: Guess: $121.62 Truth: $297.95 Error: $176.32 SLE: 0.79 Item: Dell Latitude D620 R...
# 215: Guess: $415.00 Truth: $399.99 Error: $15.01 SLE: 0.00 Item: acer Aspire 5 Laptop...
# 216: Guess: $442.00 Truth: $599.00 Error: $157.00 SLE: 0.09 Item: Elk 30 by 6-Inch Viv...
# 217: Guess: $220.38 Truth: $105.99 Error: $114.39 SLE: 0.53 Item: Barbie Top Model Dol...
# 218: Guess: $352.75 Truth: $689.00 Error: $336.25 SLE: 0.45 Item: Danby Designer 20-In...
# 219: Guess: $430.25 Truth: $404.99 Error: $25.26 SLE: 0.00 Item: FixtureDisplays® Met...
# 220: Guess: $190.38 Truth: $207.76 Error: $17.38 SLE: 0.01 Item: ACDelco GM Original ...
# 221: Guess: $191.00 Truth: $171.82 Error: $19.18 SLE: 0.01 Item: EBC Premium Street B...
# 222: Guess: $320.50 Truth: $293.24 Error: $27.26 SLE: 0.01 Item: FXR Men's Boost FX J...
# 223: Guess: $448.00 Truth: $374.95 Error: $73.05 SLE: 0.03 Item: SuperATV Scratch Res...
# 224: Guess: $112.88 Truth: $111.99 Error: $0.89 SLE: 0.00 Item: SBU 3 Layer All Weat...
# 225: Guess: $47.50 Truth: $42.99 Error: $4.51 SLE: 0.01 Item: 2 Pack Outdoor Broch...
# 226: Guess: $134.12 Truth: $116.71 Error: $17.42 SLE: 0.02 Item: Monroe Shocks & Stru...
# 227: Guess: $203.38 Truth: $118.61 Error: $84.77 SLE: 0.29 Item: Elements of Design M...
# 228: Guess: $115.00 Truth: $147.12 Error: $32.12 SLE: 0.06 Item: GM Genuine Parts Air...
# 229: Guess: $264.50 Truth: $119.99 Error: $144.51 SLE: 0.62 Item: Baseus USB C Docking...
# 230: Guess: $283.50 Truth: $369.98 Error: $86.48 SLE: 0.07 Item: Whitehall™ Personali...
# 231: Guess: $260.50 Truth: $315.55 Error: $55.05 SLE: 0.04 Item: Pro Circuit Works Pi...
# 232: Guess: $271.25 Truth: $190.99 Error: $80.26 SLE: 0.12 Item: HYANKA 15 1200W Prof...
# 233: Guess: $244.00 Truth: $155.00 Error: $89.00 SLE: 0.20 Item: Bluetooth X6BT Card ...
# 234: Guess: $330.25 Truth: $349.99 Error: $19.74 SLE: 0.00 Item: AIRAID Cold Air Inta...
# 235: Guess: $250.00 Truth: $249.99 Error: $0.01 SLE: 0.00 Item: Bostingner Shower Fa...
# 236: Guess: $24.41 Truth: $42.99 Error: $18.58 SLE: 0.30 Item: PIT66 Front Bumper T...
# 237: Guess: $12.19 Truth: $17.99 Error: $5.80 SLE: 0.13 Item: Caseology Bumpy Comp...
# 238: Guess: $352.75 Truth: $425.00 Error: $72.25 SLE: 0.03 Item: Fleck 2510 Timer Mec...
# 239: Guess: $278.75 Truth: $249.99 Error: $28.76 SLE: 0.01 Item: Haloview MC7108 Wire...
# 240: Guess: $64.62 Truth: $138.23 Error: $73.60 SLE: 0.57 Item: Schmidt Spiele - Man...
# 241: Guess: $275.50 Truth: $414.99 Error: $139.49 SLE: 0.17 Item: Corsa 14333 Tip Kit ...
# 242: Guess: $164.00 Truth: $168.28 Error: $4.28 SLE: 0.00 Item: Hoshizaki FM116A Fan...
# 243: Guess: $266.50 Truth: $199.99 Error: $66.51 SLE: 0.08 Item: BAINUO Antler Chande...
# 244: Guess: $145.75 Truth: $126.70 Error: $19.05 SLE: 0.02 Item: DNA MOTORING Smoke L...
# 245: Guess: $3.97 Truth: $5.91 Error: $1.94 SLE: 0.11 Item: Wera Stainless 3840/...
# 246: Guess: $247.12 Truth: $193.06 Error: $54.06 SLE: 0.06 Item: Celestron - PowerSee...
# 247: Guess: $257.00 Truth: $249.99 Error: $7.01 SLE: 0.00 Item: NHOPEEW Android Car ...
# 248: Guess: $109.50 Truth: $64.12 Error: $45.38 SLE: 0.28 Item: Other Harmonica A)
# F...
# 249: Guess: $256.50 Truth: $114.99 Error: $141.51 SLE: 0.64 Item: Harley Air Filter Ve...
# 250: Guess: $402.50 Truth: $926.00 Error: $523.50 SLE: 0.69 Item: Elite Screens Edge F...
